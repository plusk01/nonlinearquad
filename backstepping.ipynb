# %% [markdown]
# # Backstepping Control of Quadrotors

# %% [markdown]
# Resources:
# - http://www.mic-journal.no/pdf/1999/mic-1999-2-3.pdf
# - http://www.uotechnology.edu.iq/dep-cse/studentsaffairs/Backstepping%20Control%20Design%20Lab.pdf
